# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Question: 4

# %%
page = requests.get('https://www.bewakoof.com/bestseller?sort=popular%20')

page
# Out:
# <Response [200]>

# %%
# soup = BeautifulSoup(page.content)

# soup

# %%
item = []

for i in soup.find_all('h2',class_="clr-shade4 h3-p-name undefined false"):
    item.append(i.text)
    
item
# Out:
# ["Women's Blue Round in Bugs Graphic Printed Oversized Short Top",
#  "Women's Blue Inner Peace Graphic Printed Boyfriend T-shirt",
#  "Men's Black Create Good Stories Typography T-shirt",
#  "Men's Black T-shirt",
#  "Women's Blue Hello Sunshine Graphic Printed Boyfriend T-shirt",
#  "Men's Jet Black Vest",
#  "Men's Black Iron Man of War Graphic Printed Vest",
#  "Men's White T-shirt",
#  "Men's Red T-shirt",
#  "Women's Grey Oversized Acid Wash T-shirt"]

# %%
price = []

for i in soup.find_all('div',class_="discountedPriceText clr-p-black false"):
    price.append(i.text.replace('₹','Rs.'))
    
price
# Out:
# ['Rs.487',
#  'Rs.389',
#  'Rs.369',
#  'Rs.599',
#  'Rs.379',
#  'Rs.409',
#  'Rs.499',
#  'Rs.469',
#  'Rs.609',
#  'Rs.399']

# %%
image = []

for i in soup.find_all('img',class_="productImgTag"):
    image.append(i['src'])
    
image
# Out:
# ['https://images.bewakoof.com/t640/women-s-blue-round-in-bugs-graphic-printed-oversized-short-top-589789-1707221362-1.jpg',
#  'https://images.bewakoof.com/t640/women-s-blue-inner-peace-graphic-printed-boyfriend-t-shirt-295707-1695391077-1.jpg',
#  'https://images.bewakoof.com/t640/men-s-black-create-good-stories-typography-t-shirt-283013-1715257551-1.jpg',
#  'https://images.bewakoof.com/t640/men-s-black-t-shirt-106-1701423878-1.jpg',
#  'https://images.bewakoof.com/t640/hello-sunshine-boyfriend-t-shirt-navy-blue-296647-1655748887-1.jpg',
#  'https://images.bewakoof.com/t640/jet-black-vest-210687-1659522825-1.jpg',
#  'https://images.bewakoof.com/t640/iron-man-of-war-vest-avl-220651-1655748304-1.jpg',
#  'https://images.bewakoof.com/t640/men-s-white-t-shirt-105-1702967985-1.jpg',
#  'https://images.bewakoof.com/t640/men-s-red-t-shirt-69875-1709214978-1.jpg',
#  'https://images.bewakoof.com/t640/women-grey-solid-tshirt-24-582039-1688996135-1.jpg']

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Product':item,'Price':price,'Image-URL':image})

df
# Out:
#                                              Product   Price  \
# 0  Women's Blue Round in Bugs Graphic Printed Ove...  Rs.487
# 1  Women's Blue Inner Peace Graphic Printed Boyfr...  Rs.389
# 2  Men's Black Create Good Stories Typography T-s...  Rs.369
# 3                                Men's Black T-shirt  Rs.599
# 4  Women's Blue Hello Sunshine Graphic Printed Bo...  Rs.379
# 5                               Men's Jet Black Vest  Rs.409
# 6   Men's Black Iron Man of War Graphic Printed Vest  Rs.499
# 7                                Men's White T-shirt  Rs.469
# 8                                  Men's Red T-shirt  Rs.609
# 9           Women's Grey Oversized Acid Wash T-shirt  Rs.399
#
#                                            Image-URL
# 0  https://images.bewakoof.com/t640/women-s-blue-...
# 1  https://images.bewakoof.com/t640/women-s-blue-...
# 2  https://images.bewakoof.com/t640/men-s-black-c...
# 3  https://images.bewakoof.com/t640/men-s-black-t...
# ...

# %% [markdown]
# # Question : 5

# %%
res = requests.get('https://www.cnbc.com/world/?region=world')

res
# Out:
# <Response [200]>

# %%
# soup = BeautifulSoup(res.content, 'html.parser')
# soup

# %%
news = []

for i in soup.find_all('a',class_="LatestNews-headline"):
    news.append(i.text)
    
news
# Out:
# ['Report: These cereals have the most fiber, protein and other essential nutrients',
#  'Why a couple saving for a home in Chicago bought one in Italy instead ',
#  'What we expect from Costco earnings and 3 others, and Fed favorite inflation gauge',
#  "Here's what it's like inside the operating room when someone gets a brain implant",
#  "Couple earns $270,000 a year, but doesn't feel like it's enough",
#  'How digital health companies are capitalizing on the GLP-1 boom',
#  'Collectors may pay thousands for $1 bills with this printing error—how to check',
#  "'Pregnancy discrimination across corporate America is still rampant': author ",
#  "Self-made millionaire: This simple 3-word question can 'change your life'",
#  'Rise of resort day passes offers travelers luxury on a budget',
#  'Angela Bassett: My mom used this 5-word phrase to raise successful children',
#  "The Fed probably won't be delivering any interest rate cuts this summer ",
# ...

# %%
links = []

for i in soup.find_all('a',class_="LatestNews-headline"):
    links.append(i['href'])
        
links
# Out:
# ['https://www.cnbc.com/2024/05/25/these-cereals-have-the-most-fiber-protein-and-other-essential-nutrients.html',
#  'https://www.cnbc.com/2024/05/25/couple-saving-first-us-home-bought-italy-instead.html',
#  'https://www.cnbc.com/2024/05/25/costco-earnings-and-3-others-and-the-fed-favorite-inflation-gauge.html',
#  'https://www.cnbc.com/2024/05/25/neuralink-competitor-precision-neuroscience-is-testing-its-brain-implant-in-humans.html',
#  'https://www.cnbc.com/2024/05/25/debt-free-couple-earning-six-figures-doesnt-feel-like-its-enough.html',
#  'https://www.cnbc.com/2024/05/25/digital-health-companies-are-launching-programs-around-glp-1s-.html',
#  'https://www.cnbc.com/2024/05/25/collectors-may-pay-thousands-for-dollar-bills-with-printing-error.html',
#  'https://www.cnbc.com/2024/05/25/pregnancy-discrimination-still-rampant-in-corporate-america-author.html',
#  'https://www.cnbc.com/2024/05/25/rse-ventures-ceo-matt-higgins-use-this-question-to-fight-imposter-syndrome.html',
# ...

# %%
time = []

for i in soup.find_all('time',class_="LatestNews-timestamp"):
    time.append(i.text)
    
time
# Out:
# ['14 Hours Ago',
#  '14 Hours Ago',
#  '15 Hours Ago',
#  '15 Hours Ago',
#  '15 Hours Ago',
#  '16 Hours Ago',
#  '16 Hours Ago',
#  '16 Hours Ago',
#  '16 Hours Ago',
#  '17 Hours Ago',
#  '17 Hours Ago',
#  '17 Hours Ago',
#  '17 Hours Ago',
#  '17 Hours Ago',
#  '17 Hours Ago',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024',
#  'May 24, 2024']

# %%
df = pd.DataFrame({'Headlines':news,'Release':time,'News-Link':links})

df
# Out:
#                                             Headlines       Release  \
# 0   Report: These cereals have the most fiber, pro...  14 Hours Ago
# 1   Why a couple saving for a home in Chicago boug...  14 Hours Ago
# 2   What we expect from Costco earnings and 3 othe...  15 Hours Ago
# 3   Here's what it's like inside the operating roo...  15 Hours Ago
# 4   Couple earns $270,000 a year, but doesn't feel...  15 Hours Ago
# 5   How digital health companies are capitalizing ...  16 Hours Ago
# 6   Collectors may pay thousands for $1 bills with...  16 Hours Ago
# 7   'Pregnancy discrimination across corporate Ame...  16 Hours Ago
# 8   Self-made millionaire: This simple 3-word ques...  16 Hours Ago
# 9   Rise of resort day passes offers travelers lux...  17 Hours Ago
# 10  Angela Bassett: My mom used this 5-word phrase...  17 Hours Ago
# 11  The Fed probably won't be delivering any inter...  17 Hours Ago
# 12  This power management stock could win big from...  17 Hours Ago
# ...

# %% [markdown]
# # Question : 6

# %%
source = requests.get('https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/')

source
# Out:
# <Response [200]>

# %%
# soup = BeautifulSoup(source.content)

# soup

# %%
titles = []

for i in soup.find_all('h2',class_="h5 article-title"):
    titles.append(i.text[23:155])
    
titles
# Out:
# ['Implementation of artificial intelligence in agriculture for optimisation of irrigation and application of pesticides and herbicides',
#  'Review of agricultural IoT technology\r\n                \n',
#  'A comprehensive review on automation in agriculture using artificial intelligence\r\n                \n',
#  'Automation and digitization of agriculture using artificial intelligence and internet of things\r\n                \n',
#  'Real-time hyperspectral imaging for the in-field estimation of strawberry ripeness with deep learning\r\n                \n',
#  'A review of imaging techniques for plant disease detection\r\n                \n',
#  'Deep learning based computer vision approaches for smart agricultural applications\r\n                \n',
#  'Applications of electronic nose (e-nose) and electronic tongue (e-tongue) in food quality-related properties determination: A review',
#  'Fruit ripeness classification: A survey\r\n                \n',
# ...

# %%
release = [] 

for i in soup.find_all('p',class_="article-date"):
    release.append(i.text)
    
release
# Out:
# ['2020',
#  '2022',
#  'June 2019',
#  '2021',
#  '2020',
#  '2020',
#  '2022',
#  '2020',
#  'March 2023',
#  'June 2023',
#  '2022',
#  'March 2024',
#  'September 2023',
#  '2021',
#  'March 2024',
#  '2022',
#  '2022',
#  '2022',
#  'September 2023',
#  '2020',
#  '2020',
#  'December 2023',
#  'March 2024',
#  '2022',
#  'June 2024']

# %%
authors = []

for i in soup.find_all('p',class_="article-authors"):
    authors.append(i.text.replace('|',','))
    
authors
# Out:
# [' Tanha Talaviya ,  Dhara Shah ,  Nivedita Patel ,  Hiteshri Yagnik ,  Manan Shah',
#  ' Jinyuan Xu ,  Baoxing Gu ,  Guangzhao Tian',
#  ' Kirtan Jha ,  Aalap Doshi ,  Poojan Patel ,  Manan Shah',
#  ' A. Subeesh ,  C.R. Mehta',
#  ' Zongmei Gao ,  Yuanyuan Shao ,  Guantao Xuan ,  Yongxian Wang ,  Yi Liu ,  Xiang Han',
#  ' Vijai Singh ,  Namita Sharma ,  Shikha Singh',
#  ' V.G. Dhanya ,  A. Subeesh ,  N.L. Kushwaha ,  Dinesh Kumar Vishwakarma ,  T. Nagesh Kumar ,  G. Ritika ,  A.N. Singh',
#  ' Juzhong Tan ,  Jie Xu',
#  ' Matteo Rizzo ,  Matteo Marcuzzo ,  Alessandro Zangari ,  Andrea Gasparetto ,  Andrea Albarelli',
#  ' Vilani Sachithra ,  L.D.C.S. Subhashini',
#  ' Ananda S. Paymode ,  Vandana B. Malode',
#  ' P. Isaac Ritharson ,  Kumudha Raimond ,  X. Anitha Mary ,  Jennifer Eunice Robert ,  Andrew J',
#  ' Md Taimur Ahad ,  Yan Li ,  Bo Song ,  Touhid Bhuiyan',
#  ' Punam Bedi ,  Pushkar Gole',
# ...

# %%
df = pd.DataFrame({'Paper':titles,'Release Year':release,'Authors':authors})

df
# Out:
#                                                 Paper    Release Year  \
# 0   Implementation of artificial intelligence in a...            2020
# 1   Review of agricultural IoT technology\r\n     ...            2022
# 2   A comprehensive review on automation in agricu...       June 2019
# 3   Automation and digitization of agriculture usi...            2021
# 4   Real-time hyperspectral imaging for the in-fie...            2020
# 5   A review of imaging techniques for plant disea...            2020
# 6   Deep learning based computer vision approaches...            2022
# 7   Applications of electronic nose (e-nose) and e...            2020
# 8   Fruit ripeness classification: A survey\r\n   ...      March 2023
# 9   How artificial intelligence uses to achieve th...       June 2023
# 10  Transfer Learning for Multi-Crop Leaf Disease ...            2022
# 11  DeepRice: A deep learning and deep feature bas...      March 2024
# ...

# %% [markdown]
# # Question : 3

# %%
page = requests.get('https://www.nobroker.in/property/sale/bangalore/multiple?searchParam=...&radius=2.0&city=bangalore&locality=Indiranagar,Rajajinagar,Jayanagar')

page
# Out:
# <Response [200]>

# %%
# soup = BeautifulSoup(page.content)

# soup

# %%
titles = []

for i in soup.find_all('h2',class_="heading-6 flex items-center font-semi-bold m-0"):
    titles.append(i.text)
        
titles
# Out:
# ['3 BHK Flat In Silicon Sattva For Sale  In Jayanagar',
#  '3 BHK House For Sale  In Agrahara Dasarahalli',
#  '3 BHK Apartment In Amarjyothi Apartments For Sale  In Jayanagar 6th Block, Jayanagar',
#  '2 BHK House For Sale  In Rajajinagar',
#  '4+ BHK House For Sale  In Jayanagar',
#  '2 BHK Apartment In Alpine Regency For Sale  In Jayanagar',
#  '3 BHK Apartment In Suraj Lakshmi Apartments For Sale  In Basavanagudi',
#  '2 BHK Flat In Bindi Sundar Residency For Sale  In Rajajinagar',
#  '3 BHK House For Sale  In Jayanagar',
#  '3 BHK Flat For Sale  In Rajajinagar',
#  '4+ BHK Flat For Sale  In Rdx Studios',
#  '3 BHK Flat In Ltg Sr Grand For Sale  In Rajaji Nagar',
#  '4+ BHK House For Sale  In Indiranagar',
#  '3 BHK House For Sale  In Jayanagar',
#  '3 BHK Apartment In Gokul Lake View Apartments For Sale  In Jayanagar',
#  '4 BHK House For Sale  In Indiranagar',
#  '3 BHK Flat In Santa Clara Apartments For Sale  In Jayanagar',
#  '4+ BHK House For Sale  In Indiranagar',
# ...

# %%
loc = []

for i in soup.find_all('div',class_="mt-0.5p overflow-hidden overflow-ellipsis whitespace-nowrap max-w-70 text-gray-light leading-4 po:mb-0.1p po:max-w-95"):
    loc.append(i.text)
    
loc
# Out:
# ['4th Main Road, Jayanagar 6th Block,Near Nimishamba Temple',
#  'Independent House, near Shell petrol bunk and Raheja Apartments',
#  'Amarjyothi Apartments\xa0 Jayanagar 6th block, Bangalore',
#  'Independent House, 2nd Stage, near Sri Vani International School',
#  'Independent House, No:1,First cross street,RBI colony.Tilak nagar police station',
#  'Alpine Regency\xa0  Alpine Regency, 10th D Main Rd, 1st Block, Jaya Nagar East, Jayanagar, Bengaluru, Karnataka 560011, India',
#  'Suraj Lakshmi Apartments\xa0 34/1, 1st Main Rd, Tata Silk Farm, Basavanagudi, Bengaluru, Karnataka 560004, India',
#  '72nd Cross Rd, 5th Block, Jedara Halli, Rajajinagar, Bengaluru, Karnataka 560023, India',
#  'Independent House, 8thmain road 4th cross byrasandra jayanagar 1st block east.',
#  'Standalone Building, Near Spandhana nursing home',
#  'Standalone Building, Indiranagar ',
#  'west of card road near modi hospital ',
#  'Independent House, 2nd stage near  Bharat dry fruits and spices',
# ...

# %%
price = [] 

for i in soup.find_all('div',class_="p-1.5p flex border-b border-b-solid border-cardbordercolor tp:py-1p tp:px-1.5p tp:border-b-0"):
    for j in i.find_all('div',id="minDeposit"):
        for k in j.find_all('div',class_="font-semi-bold heading-6"):
            price.append(k.text.replace('₹','Rs.'))

price
# Out:
# ['Rs.1.4 Crores',
#  'Rs.1.35 Crores',
#  'Rs.1.5 Crores',
#  'Rs.1.2 Crores',
#  'Rs.5 Crores',
#  'Rs.1.65 Crores',
#  'Rs.1.2 Crores',
#  'Rs.70 Lacs',
#  'Rs.1.6 Crores',
#  'Rs.1.25 Crores',
#  'Rs.4.75 Crores',
#  'Rs.2.3 Crores',
#  'Rs.3.1 Crores',
#  'Rs.2.95 Crores',
#  'Rs.1.62 Crores',
#  'Rs.3.5 Crores',
#  'Rs.1.15 Crores',
#  'Rs.7.5 Crores',
#  'Rs.1.6 Crores',
#  'Rs.1.5 Crores',
#  'Rs.3.41 Crores',
#  'Rs.2.21 Crores',
#  'Rs.2.25 Crores',
#  'Rs.11.62 Crores',
#  'Rs.9.97 Crores',
#  'Rs.1.4 Crores']

# %%
emi = []

for i in soup.find_all('div',class_="p-1.5p flex border-b border-b-solid border-cardbordercolor tp:py-1p tp:px-1.5p tp:border-b-0"):
    for j in i.find_all('div',id="roomType"):
        emi.append(j.text.replace('₹','Rs.'))

emi
# Out:
# ['Rs.80,240/Month',
#  'Rs.77,374/Month',
#  'Rs.85,971/Month',
#  'Rs.68,777/Month',
#  'Rs.2.87 Lacs/Month',
#  'Rs.94,568/Month',
#  'Rs.68,777/Month',
#  'Rs.40,120/Month',
#  'Rs.91,703/Month',
#  'Rs.71,643/Month',
#  'Rs.2.72 Lacs/Month',
#  'Rs.1.32 Lacs/Month',
#  'Rs.1.78 Lacs/Month',
#  'Rs.1.69 Lacs/Month',
#  'Rs.92,849/Month',
#  'Rs.2.01 Lacs/Month',
#  'Rs.65,911/Month',
#  'Rs.4.3 Lacs/Month',
#  'Rs.91,703/Month',
#  'Rs.85,971/Month',
#  'Rs.1.95 Lacs/Month',
#  'Rs.1.27 Lacs/Month',
#  'Rs.1.29 Lacs/Month',
#  'Rs.6.66 Lacs/Month',
#  'Rs.5.72 Lacs/Month',
#  'Rs.80,240/Month']

# %%
areas = []

for i in soup.find_all('div',class_="flex flex-col w-33pe items-center tp:w-half po:w-full"):
    for j in i.find_all('div',class_="flex"):
        areas.append(j.text)
    
areas
# Out:
# ['1,485 sqft',
#  '2,400 sqft',
#  '1,552 sqft',
#  '1,200 sqft',
#  '4,000 sqft',
#  '1,320 sqft',
#  '1,226 sqft',
#  '896 sqft',
#  '1,000 sqft',
#  '1,050 sqft',
#  '3,624 sqft',
#  '1,865 sqft',
#  '4,800 sqft',
#  '1,600 sqft',
#  '1,852 sqft',
#  '4,800 sqft',
#  '1,395 sqft',
#  '2,800 sqft',
#  '1,800 sqft',
#  '1,357 sqft',
#  '2,504 sqft',
#  '1,657 sqft',
#  '2,000 sqft',
#  '3,647 sqft',
#  '3,147 sqft',
#  '1,485 sqft']

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Title':titles,'Location':loc,'Apartment Price':price,'EMI':emi,'Buildup-Area':areas})

df
# Out:
#                                                 Title  \
# 0   3 BHK Flat In Silicon Sattva For Sale  In Jaya...
# 1       3 BHK House For Sale  In Agrahara Dasarahalli
# 2   3 BHK Apartment In Amarjyothi Apartments For S...
# 3                2 BHK House For Sale  In Rajajinagar
# 4                 4+ BHK House For Sale  In Jayanagar
# 5   2 BHK Apartment In Alpine Regency For Sale  In...
# 6   3 BHK Apartment In Suraj Lakshmi Apartments Fo...
# 7   2 BHK Flat In Bindi Sundar Residency For Sale ...
# 8                  3 BHK House For Sale  In Jayanagar
# 9                 3 BHK Flat For Sale  In Rajajinagar
# 10               4+ BHK Flat For Sale  In Rdx Studios
# 11  3 BHK Flat In Ltg Sr Grand For Sale  In Rajaji...
# 12              4+ BHK House For Sale  In Indiranagar
# 13                 3 BHK House For Sale  In Jayanagar
# 14  3 BHK Apartment In Gokul Lake View Apartments ...
# 15               4 BHK House For Sale  In Indiranagar
# ...

# %% [markdown]
# # Question : 1

# %%
page = requests.get('https://www.imdb.com/list/ls056092300/', headers={'User-Agent': 'Mozilla/5.0'})

page
# Out:
# <Response [200]>

# %%
# soup = BeautifulSoup(page.content)

# soup

# %%
name = []

for i in soup.find_all('div',class_="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b189961a-9 iALATN dli-title"):
    for tag in i.find_all('a',class_="ipc-title-link-wrapper"):
        name.append(tag.text[3:])
    
name
# Out:
# ['Ship of Theseus',
#  'Iruvar',
#  'Kaagaz Ke Phool',
#  'Lagaan: Once Upon a Time in India',
#  'Pather Panchali',
#  'Charulata',
#  'Rang De Basanti',
#  'Dev.D',
#  '3 Idiots',
#  ' Awaara',
#  ' Nayakan',
#  ' Aparajito',
#  ' Pushpaka Vimana',
#  ' Pyaasa',
#  ' Ghatashraddha',
#  ' Sholay',
#  ' Aradhana',
#  ' Do Ankhen Barah Haath',
#  ' Bombay',
#  ' Neecha Nagar',
#  ' Do Bigha Zamin',
#  ' Garm Hava',
#  ' Piravi',
#  ' Mughal-E-Azam',
#  ' Amma Ariyan',
#  ' Madhumati',
#  ' Goopy Gyne Bagha Byne',
#  ' Gangs of Wasseypur',
#  ' Guide',
#  ' Satya',
#  ' Roja',
#  ' Mr. India',
#  ' Meghe Dhaka Tara',
#  ' Harishchandrachi Factory',
#  ' Masoom',
#  ' Agneepath',
#  ' Tabarana Kathe',
#  ' Zakhm',
#  ' Dil Chahta Hai',
#  ' Bhaag Milkha Bhaag',
#  ' Chupke Chupke',
#  ' Dilwale Dulhania Le Jayenge',
#  ' Taare Zameen Par',
#  ' Ardh Satya',
#  ' Bhumika',
#  ' Enthiran',
#  ' Sadma',
#  ' Shwaas',
#  ' Lamhe',
#  ' Haqeeqat',
#  ' Shree 420',
# ...

# %%
year = []

for i in soup.find_all('div',class_="sc-b189961a-0 hBZnfJ"):
    for j in i.find_all('div',class_="sc-b189961a-7 feoqjK dli-title-metadata"):
        year.append(j.text[0:4])
        
year
# Out:
# ['2012',
#  '1997',
#  '1959',
#  '2001',
#  '1955',
#  '1964',
#  '2006',
#  '2009',
#  '2009',
#  '1951',
#  '1987',
#  '1956',
#  '1987',
#  '1957',
#  '1977',
#  '1975',
#  '1969',
#  '1957',
#  '1995',
#  '1946',
#  '1953',
#  '1974',
#  '1989',
#  '1960',
#  '1986',
#  '1958',
#  '1969',
#  '2012',
#  '1965',
#  '1998',
#  '1992',
#  '1987',
#  '1960',
#  '2009',
#  '1983',
#  '1990',
#  '1986',
#  '1998',
#  '2001',
#  '2013',
#  '1975',
#  '1995',
#  '2007',
#  '1983',
#  '1977',
#  '2010',
#  '1983',
#  '2004',
#  '1991',
#  '1964',
#  '1955',
#  '2002',
#  '1994',
#  '2012',
#  '1994',
#  '2004',
#  '2004',
#  '1976',
#  '1975',
#  '2012',
#  '1967',
#  '1972',
#  '2003',
#  '1960',
#  '1962',
#  '1977',
#  '1963',
#  '2001',
#  '2008',
#  '2002',
#  '1989',
#  '1994',
#  '2013',
#  '1983',
#  '2003',
#  '1984',
#  '1971',
#  '2006',
#  '2012',
#  '2003',
#  '1982',
#  '2007',
#  '1994',
#  '1964',
#  '1978',
#  '1969',
#  '1997',
#  '2005',
#  '1955',
#  '2009',
# ...

# %%
rating = []

for i in soup.find_all('div',class_="sc-e2dbc1a3-0 ajrIH sc-b189961a-2 fkPBP dli-ratings-container"):
    for j in i.find_all('span',class_="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating"):
        rating.append(j.text[0:3])
    
rating
# Out:
# ['8.0',
#  '8.4',
#  '7.8',
#  '8.1',
#  '8.2',
#  '8.1',
#  '8.1',
#  '7.9',
#  '8.4',
#  '7.8',
#  '8.7',
#  '8.2',
#  '8.6',
#  '8.3',
#  '7.6',
#  '8.1',
#  '7.6',
#  '8.4',
#  '8.1',
#  '6.6',
#  '8.3',
#  '8.0',
#  '7.8',
#  '8.1',
#  '7.4',
#  '7.8',
#  '8.7',
#  '8.2',
#  '8.3',
#  '8.3',
#  '8.1',
#  '7.7',
#  '7.8',
#  '8.4',
#  '8.4',
#  '7.6',
#  '8.1',
#  '7.9',
#  '8.1',
#  '8.2',
#  '8.3',
#  '8.0',
#  '8.3',
#  '8.1',
#  '7.4',
#  '7.1',
#  '8.3',
#  '8.1',
#  '7.2',
#  '7.8',
#  '7.9',
#  '8.3',
#  '7.5',
#  '8.2',
#  '7.5',
#  '7.8',
#  '8.4',
#  '7.7',
#  '7.6',
#  '7.8',
#  '7.9',
#  '7.2',
#  '8.0',
#  '7.1',
#  '8.1',
#  '7.5',
#  '8.1',
#  '7.6',
#  '8.2',
#  '7.9',
#  '6.7',
#  '7.7',
#  '7.7',
#  '8.8',
#  '8.1',
#  '8.1',
#  '7.2',
#  '7.2',
#  '8.2',
#  '7.8',
#  '8.3',
#  '7.7',
#  '8.0',
#  '7.3',
#  '7.8',
#  '7.2',
#  '7.9',
#  '7.2',
#  '7.7',
#  '7.5',
#  '7.5',
#  '8.3',
#  '7.9',
#  '7.7',
#  '8.3',
#  '8.4',
#  '8.2',
#  '7.3',
#  '8.1',
#  '8.0']

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Title':name,  'Year of Release':year,  'Rating':rating})

df
# Out:
#                                 Title Year of Release Rating
# 0                     Ship of Theseus            2012    8.0
# 1                              Iruvar            1997    8.4
# 2                     Kaagaz Ke Phool            1959    7.8
# 3   Lagaan: Once Upon a Time in India            2001    8.1
# 4                     Pather Panchali            1955    8.2
# ..                                ...             ...    ...
# 95                        Apur Sansar            1959    8.4
# 96                        Kanchivaram            2008    8.2
# 97                    Monsoon Wedding            2001    7.3
# 98                              Black            2005    8.1
# 99                          . Deewaar            1975    8.0
#
# [100 rows x 3 columns]

# %% [markdown]
# # Question : 2

# %%
response = requests.get('https://www.patreon.com/coreyms')

response
# Out:
# <Response [200]>

# %%
# soup = BeautifulSoup(response.content, 'html.parser')

# soup

# %%
posts = []

for i in soup.find_all('div',class_="sc-bBHxTw iloeMK"):
    for span in i.find_all('span',class_="sc-1cvoi1y-0 hxhWXn"):
        posts.append(j.text)
                
posts
# Out:
# []

# %%
dates = []

for i in soup.find_all('div',class_="sc-lgu5zg-0 dXpjXs"):
    for j in i.find_all('span',class_="sc-1cvoi1y-0 hxhWXn"):
        dates.append(j.text)
                        
dates
# Out:
# []

# %%
likes = []

for i in soup.find_all('div',class_="sc-jrQzAO knZGTZ"):
    likes.append(i.text)
        
likes
# Out:
# []

# %%
df = pd.DataFrame({'Heading':posts,'Date':dates,'Like':likes})

df
# Out:
# Empty DataFrame
# Columns: [Heading, Date, Like]
# Index: []
